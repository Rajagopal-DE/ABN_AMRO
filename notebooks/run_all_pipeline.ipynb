# %%
import sys
import yaml
 
# clear cached modules to always use latest framework code
for mod in list(sys.modules.keys()):
    if mod in ("etl_utils", "dq_checker", "executor"):
        del sys.modules[mod]
 
notebook_path  = dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()
repo_root      = "/Workspace" + "/".join(notebook_path.split("/")[:-2])
framework_path = repo_root + "/framework"
configs_path   = repo_root + "/configs"
sys.path.append(framework_path)
 
from executor import run_pipeline, run_gold
 

with open(f"{configs_path}/global_config.yaml") as f:
    global_cfg = yaml.safe_load(f)
catalog = global_cfg["catalog"]

# %%
run_pipeline("pipeline_market.yaml")

# %%
run_pipeline("pipeline_clients.yaml")

# %%
run_pipeline("pipeline_credits.yaml")

# %%
run_pipeline("pipeline_collaterals.yaml")

# %%
run_gold()

# %%
spark.table("project2.gold.credit_risk_fact").orderBy("overall_risk").display()
